# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # biblioteca para plotar gráficos
import seaborn as sns
# %matplotlib inline

# %%
data = np.loadtxt("Data1_Cotovelo.txt", delimiter=',')
# 1a remada descartar

# %%
x = data[:, 0]
y = data[:, 1]
plt.plot(x, y)

# %% [markdown]
# # 3 remadas completas
#
# Gráficos gerados por partes a cada remada
#
# ![teste](1a_2a_3a_remadacompleta_cotovelo.png "3 remadas completas")
