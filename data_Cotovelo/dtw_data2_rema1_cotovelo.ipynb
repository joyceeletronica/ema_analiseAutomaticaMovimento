# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # biblioteca para plotar gráficos
import seaborn as sns
# %matplotlib inline

# %%
data = np.loadtxt("Data2_Rema1_Cotovelo.txt", delimiter=',')

# %%
x = data[:, 0]
y = data[:, 1]
plt.plot(x, y)
